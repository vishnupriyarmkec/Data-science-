# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('1/1/2000',periods=10),columns=list('ABCD'))

# %%
ds.plot()
# Out:
# <AxesSubplot:>

# %%
ds.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.area()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(40,4),columns=['A','B','C','D'])
ds.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
ds=pd.read_csv("C:\president_heights.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27500\3898045331.py in <module>
# ----> 1 ds=pd.read_csv("C:\president_heights.csv")
#
# NameError: name 'pd' is not defined

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27500\2369097233.py in <module>
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
ds.plot.scatter(x='order',y='name')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27500\2821005383.py in <module>
# ----> 1 ds.plot.scatter(x='order',y='name')
#
# NameError: name 'ds' is not defined

# %%
ds=pd.read_csv("C:\president_heights.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27500\3898045331.py in <module>
# ----> 1 ds=pd.read_csv("C:\president_heights.csv")
#
# NameError: name 'pd' is not defined

# %%
data=[1,2,3,4]

# %%
data
# Out:
# [1, 2, 3, 4]

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
data[2]
# Out:
# 3

# %%
df[0]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: 0, dtype: int64

# %%
df[0][2]
# Out:
# 3

# %%
data1=['vishnu',20],['priya',21],['rasi',13],['navya',19],['papa',18]

# %%
df=pd.DataFrame(data1)

# %%
df
# Out:
#         0   1
# 0  vishnu  20
# 1   priya  21
# 2    rasi  13
# 3   navya  19
# 4    papa  18

# %%
df.iloc[2]
# Out:
# 0    rasi
# 1      13
# Name: 2, dtype: object

# %%
df[:][2:3]
# Out:
#       0   1
# 2  rasi  13

# %%
df=pd.DataFrame(data1,columns=['name','age'])

# %%
df
# Out:
#      name  age
# 0  vishnu   20
# 1   priya   21
# 2    rasi   13
# 3   navya   19
# 4    papa   18

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
data2={'Name':['sindhu','bhavana','swetha','sai','teju'],'department':['cse','it','ece','eee','me']}

# %%
data2
# Out:
# {'Name': ['sindhu', 'bhavana', 'swetha', 'sai', 'teju'],
#  'department': ['cse', 'it', 'ece', 'eee', 'me']}

# %%
df=pd.DataFrame(data2,columns=['Name','department'])

# %%
df
# Out:
#       Name department
# 0   sindhu        cse
# 1  bhavana         it
# 2   swetha        ece
# 3      sai        eee
# 4     teju         me

# %%
df=pd.DataFrame(data2,columns=['Name','department'],index=['first','second','third','fourth','fifth'])

# %%
df
# Out:
#            Name department
# first    sindhu        cse
# second  bhavana         it
# third    swetha        ece
# fourth      sai        eee
# fifth      teju         me

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27500\3380326488.py in <module>
# ----> 1 df.plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     325     def generate(self):
# ...
